# %% [markdown]
# # Proyek Analisis Data: E-Commerce Public Dataset
# - **Nama:** Mhd. Reza Kurniawan Lubis
# - **Email:** rezakurniawan432@gmail.com
# - **Email Bangkit:** m319d4ky2012@bangkit.academy
# - **ID Dicoding:**

# %% [markdown]
# ## Menentukan Pertanyaan Bisnis

# %% [markdown]
# ### After doing a research about the dataset, I am curios about several things:
# 1. which products are the best sellers.
# 2. which regions make the most purchases.
# 3. grouping customers who are loyal customers and order a lot, loyal customers but order a little at or rarely buy but immediately a lot, and rarely buy and only a little.
#
# #### For context number 1, the questions are:
# - which product category has the highest number of sales in the past 2 years?
# - what percentage did the best-selling product contribute to total sales in the same period?
# - what promotional strategies can be implemented to increase sales of this best-selling product by 20% in the next 1 year?
#
# #### For context number 2, the questions are:
# - which city has the highest number of orders over the past 2 years?
# - what percentage did the city contribute to the company's total revenue over the same period?
# - how to increase the number of orders from other cities by 20% in the next 1 year?
#
# #### For context number 3, the questions are:
# - what percentage of loyal customers and order a lot?
# - what percentage of loyal customers but order a little at a time or rarely-buy customers but immediately a lot?
# - what percentage of rarely-buy customers and only a little?

# %% [markdown]
# ## Import Semua Packages/Library yang Digunakan

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.cluster import KMeans

# %% [markdown]
# ## Data Wrangling

# %% [markdown]
# ### Gathering Data

# %% [markdown]
# In this step, we will collect all the data needed. I have prepared them in data folder. All we need to do is call them here.
#
# List of the table:
# 1. customers_df
# 2. order_items_df
# 3. order_payments_df
# 4. orders_df
# 5. products_df
# 6. product_category_name_translation_df

# %%
customers_df = pd.read_csv('data/customers_dataset.csv')
customers_df
# Out:
#                             customer_id                customer_unique_id  \
# 0      06b8999e2fba1a1fbc88172c00ba8bc7  861eff4711a542e4b93843c6dd7febb0
# 1      18955e83d337fd6b2def6b18a428ac77  290c77bc529b7ac935b93aa66c333dc3
# 2      4e7b3e00288586ebd08712fdd0374a03  060e732b5b29e8181a18229c7b0b2b5e
# 3      b2b6027bc5c5109e529d4dc6358b12c3  259dac757896d24d7702b9acbbff3f3c
# 4      4f2d8ab171c80ec8364f7c12e35b23ad  345ecd01c38d18a9036ed96c73b8d066
# ...                                 ...                               ...
# 99436  17ddf5dd5d51696bb3d7c6291687be6f  1a29b476fee25c95fbafc67c5ac95cf8
# 99437  e7b71a9017aa05c9a7fd292d714858e8  d52a67c98be1cf6a5c84435bd38d095d
# 99438  5e28dfe12db7fb50a4b2f691faecea5e  e9f50caf99f032f0bf3c55141f019d99
# 99439  56b18e2166679b8a959d72dd06da27f9  73c2643a0a458b49f58cea58833b192e
# 99440  274fa6071e5e17fe303b9748641082c8  84732c5050c01db9b23e19ba39899398
#
#        customer_zip_code_prefix          customer_city customer_state
# ...

# %%
order_items_df = pd.read_csv('data/order_items_dataset.csv')
order_items_df
# Out:
#                                 order_id  order_item_id  \
# 0       00010242fe8c5a6d1ba2dd792cb16214              1
# 1       00018f77f2f0320c557190d7a144bdd3              1
# 2       000229ec398224ef6ca0657da4fc703e              1
# 3       00024acbcdf0a6daa1e931b038114c75              1
# 4       00042b26cf59d7ce69dfabb4e55b4fd9              1
# ...                                  ...            ...
# 112645  fffc94f6ce00a00581880bf54a75a037              1
# 112646  fffcd46ef2263f404302a634eb57f7eb              1
# 112647  fffce4705a9662cd70adb13d4a31832d              1
# 112648  fffe18544ffabc95dfada21779c9644f              1
# 112649  fffe41c64501cc87c801fd61db3f6244              1
#
#                               product_id                         seller_id  \
# 0       4244733e06e7ecb4970a6e2683c13e61  48436dade18ac8b2bce089ec2a041202
# 1       e5f2d52b802189ee658865ca93d83a8f  dd7ddc04e1b6c2c614352b383efe2d36
# ...

# %%
order_payments_df = pd.read_csv('data/order_payments_dataset.csv')
order_payments_df
# Out:
#                                 order_id  payment_sequential payment_type  \
# 0       b81ef226f3fe1789b1e8b2acac839d17                   1  credit_card
# 1       a9810da82917af2d9aefd1278f1dcfa0                   1  credit_card
# 2       25e8ea4e93396b6fa0d3dd708e76c1bd                   1  credit_card
# 3       ba78997921bbcdc1373bb41e913ab953                   1  credit_card
# 4       42fdf880ba16b47b59251dd489d4441a                   1  credit_card
# ...                                  ...                 ...          ...
# 103881  0406037ad97740d563a178ecc7a2075c                   1       boleto
# 103882  7b905861d7c825891d6347454ea7863f                   1  credit_card
# 103883  32609bbb3dd69b3c066a6860554a77bf                   1  credit_card
# 103884  b8b61059626efa996a60be9bb9320e10                   1  credit_card
# 103885  28bbae6599b09d39ca406b747b6632b1                   1       boleto
#
#         payment_installments  payment_value
# ...

# %%
orders_df = pd.read_csv('data/orders_dataset.csv')
orders_df
# Out:
#                                order_id                       customer_id  \
# 0      e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1      53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 2      47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
# 3      949d5b44dbf5de918fe9c16f97b45f8a  f88197465ea7920adcdbec7375364d82
# 4      ad21c59c0840e6cb83a9ceb5573f8159  8ab97904e6daea8866dbdbc4fb7aad2c
# ...                                 ...                               ...
# 99436  9c5dedf39a927c1b2549525ed64a053c  39bd1228ee8140590ac3aca26f2dfe00
# 99437  63943bddc261676b46f01ca7ac2f7bd8  1fca14ff2861355f6e5f14306ff977a7
# 99438  83c1379a015df1e13d02aae0204711ab  1aa71eb042121263aafbe80c1b562c9c
# 99439  11c177c8e97725db2631073c19f07b62  b331b74b18dc79bcdf6532d51e1637c1
# 99440  66dea50a8b16d9b4dee7af250b4be1a5  edb027a75a1449115f6b43211ae02a24
#
#       order_status order_purchase_timestamp    order_approved_at  \
# ...

# %%
products_df = pd.read_csv('data/products_dataset.csv')
products_df
# Out:
#                              product_id              product_category_name  \
# 0      1e9e8ef04dbcff4541ed26657ea517e5                         perfumaria
# 1      3aa071139cb16b67ca9e5dea641aaa2f                              artes
# 2      96bd76ec8810374ed1b65e291975717f                      esporte_lazer
# 3      cef67bcfe19066a932b7673e239eb23d                              bebes
# 4      9dc1a7de274444849c219cff195d0b71              utilidades_domesticas
# ...                                 ...                                ...
# 32946  a0b7d5a992ccda646f2d34e418fff5a0                   moveis_decoracao
# 32947  bf4538d88321d0fd4412a93c974510e6  construcao_ferramentas_iluminacao
# 32948  9a7c6041fa9592d9d9ef6cfe62a71f8c                    cama_mesa_banho
# 32949  83808703fc0706a22e264b9d75f04a2e             informatica_acessorios
# 32950  106392145fca363410d287a815be6de4                    cama_mesa_banho
#
# ...

# %%
product_category_name_translation_df = pd.read_csv('data/product_category_name_translation.csv')
product_category_name_translation_df
# Out:
#             product_category_name product_category_name_english
# 0                    beleza_saude                 health_beauty
# 1          informatica_acessorios         computers_accessories
# 2                      automotivo                          auto
# 3                 cama_mesa_banho                bed_bath_table
# 4                moveis_decoracao               furniture_decor
# ..                            ...                           ...
# 66                         flores                       flowers
# 67             artes_e_artesanato         arts_and_craftmanship
# 68                fraldas_higiene           diapers_and_hygiene
# 69  fashion_roupa_infanto_juvenil     fashion_childrens_clothes
# 70             seguros_e_servicos         security_and_services
#
# [71 rows x 2 columns]

# %% [markdown]
# ### Assessing Data

# %% [markdown]
# In this step, we will assess our data. We will make the decision about what we should do next based on this step.

# %% [markdown]
# Firs thing first, we will asses customers_df.

# %%
customers_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99441 entries, 0 to 99440
# Data columns (total 5 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   customer_id               99441 non-null  object
#  1   customer_unique_id        99441 non-null  object
#  2   customer_zip_code_prefix  99441 non-null  int64
#  3   customer_city             99441 non-null  object
#  4   customer_state            99441 non-null  object
# dtypes: int64(1), object(4)
# memory usage: 3.8+ MB

# %% [markdown]
# Next, we have to check if there is a duplicates in this table. Statistics parameters are **not necessary** because the only int is customer_zip_code_prefix and it is actually just number of the zip code that does not have to be statistically processed.

# %%
print("Duplications: ", customers_df.duplicated().sum())
# Out:
# Duplications:  0

# %% [markdown]
# We can see that there is **no problem** in this table. We will continue to assess order_items_df.

# %%
order_items_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 112650 entries, 0 to 112649
# Data columns (total 7 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   order_id             112650 non-null  object
#  1   order_item_id        112650 non-null  int64
#  2   product_id           112650 non-null  object
#  3   seller_id            112650 non-null  object
#  4   shipping_limit_date  112650 non-null  object
#  5   price                112650 non-null  float64
#  6   freight_value        112650 non-null  float64
# dtypes: float64(2), int64(1), object(4)
# memory usage: 6.0+ MB

# %% [markdown]
# We can see that the shipping_limit_date type of data is **object**, it has to be **datetime**. We will change it later in data cleaning.

# %%
print("Duplications: ", order_items_df.duplicated().sum())
# Out:
# Duplications:  0

# %%
order_items_df.describe()
# Out:
#        order_item_id          price  freight_value
# count  112650.000000  112650.000000  112650.000000
# mean        1.197834     120.653739      19.990320
# std         0.705124     183.633928      15.806405
# min         1.000000       0.850000       0.000000
# 25%         1.000000      39.900000      13.080000
# 50%         1.000000      74.990000      16.260000
# 75%         1.000000     134.900000      21.150000
# max        21.000000    6735.000000     409.680000

# %% [markdown]
# We can see that the **max** value of oreder_item_id, price, and freight_value is a too far from the value of 75%. We have to check it on-by-one to find if there is a mistake there or not.

# %%
result = order_items_df.loc[order_items_df['order_item_id'] > 15]
display(pd.DataFrame(result))
# Out:
#                                order_id  order_item_id  \
# 11947  1b15974a0141d54e36626dca3fdc731a             16
# 11948  1b15974a0141d54e36626dca3fdc731a             17
# 11949  1b15974a0141d54e36626dca3fdc731a             18
# 11950  1b15974a0141d54e36626dca3fdc731a             19
# 11951  1b15974a0141d54e36626dca3fdc731a             20
# 57312  8272b63d03f5f79c56e9e4120aec44ef             16
# 57313  8272b63d03f5f79c56e9e4120aec44ef             17
# 57314  8272b63d03f5f79c56e9e4120aec44ef             18
# 57315  8272b63d03f5f79c56e9e4120aec44ef             19
# 57316  8272b63d03f5f79c56e9e4120aec44ef             20
# 57317  8272b63d03f5f79c56e9e4120aec44ef             21
# 75118  ab14fdcfbe524636d65ee38360e22ce8             16
# 75119  ab14fdcfbe524636d65ee38360e22ce8             17
# 75120  ab14fdcfbe524636d65ee38360e22ce8             18
# 75121  ab14fdcfbe524636d65ee38360e22ce8             19
# 75122  ab14fdcfbe524636d65ee38360e22ce8             20
#
# ...

# %% [markdown]
# We can see that there are several order that have order item > 15. So it makes sense to have 21 order item.

# %%
result = order_items_df.loc[order_items_df['price'] > 3000]
display(pd.DataFrame(result))
# Out:
#                                 order_id  order_item_id  \
# 3556    0812eb902a67711a1cb742b3cdaa65ae              1
# 11249   199af31afc78c699f0dbf71fb178d4d4              1
# 12925   1d54db601b417ccdfd3b7071955e6cc7              1
# 21844   31e50461be6957a749166e97af082d0a              1
# 25648   3a4b013e014723cc38c9faa8ffdc6387              1
# 28884   41b7766bb1df487d17fb9725b78ff509              1
# 29193   426a9742b533fc6fed17d1fd6d143d7e              1
# 29787   43bdbd9dc0931d72befdf4765af6c442              1
# 36878   53c71d3953507c6239ff73917ed358c9              1
# 45843   68101694e5c5dc7330c91e1bbc36214f              1
# 56663   80dfedb6d17bf23539beeef3c768f4d7              1
# 59137   86c4eab1571921a6a6e248ed312f5a5a              1
# 62086   8dbc85d1447242f3b127dda390d56e19              1
# 65200   94fca82966c05ba707f4e7dc0c50aa3c              1
# 67456   9a3966c23190dbdbaabed08e8429c006              1
# 69142   9de73f3e6157169ad6c32b9f313c7dcb              1
# ...

# %% [markdown]
# We can see that there are several order that have price > 3000. So it makes sense to have 6735 as a price.

# %%
result = order_items_df.loc[order_items_df['freight_value'] > 200]
display(pd.DataFrame(result))
# Out:
#                                 order_id  order_item_id  \
# 1122    029c545413b10a6bd7540401f6eef0a3              1
# 3303    076d1555fb53a89b0ef4d529e527a0f6              1
# 3584    0822bcde10bb5d023755a71bc8f7797f              1
# 4878    0b055b1ac16d0401f76e361ff96926eb              1
# 5037    0b6230647ed16f4b3e70282dc4b5b87f              1
# ...                                  ...            ...
# 94173   d58096e42e1aaf58b8521e8f8b4c20dc              1
# 96597   db3b94ddef8837c5c780836f80da86c7              1
# 105903  f0a2783007ba2c431132d38c7642d5c9              1
# 107841  f5136e38d1a14a4dbd87dff67da82701              1
# 111842  fe12e676fd493885d417a34bc3917411              1
#
#                               product_id                         seller_id  \
# 1122    8d4e92265a16e69a1e1d76e67e46d72f  54219883e72aad869adfb2a54b7bfa0f
# 3303    a3cd9517ebf5a50dca25acce54f3b171  6fa9202c10491e472dffd59a3e82b2a3
# ...

# %% [markdown]
# Same like before, it makes sense to have 409.68 as a freight value. We will continue to order_payments_df.

# %%
order_payments_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 103886 entries, 0 to 103885
# Data columns (total 5 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   order_id              103886 non-null  object
#  1   payment_sequential    103886 non-null  int64
#  2   payment_type          103886 non-null  object
#  3   payment_installments  103886 non-null  int64
#  4   payment_value         103886 non-null  float64
# dtypes: float64(1), int64(2), object(2)
# memory usage: 4.0+ MB

# %%
print("Duplications: ", order_payments_df.duplicated().sum())
# Out:
# Duplications:  0

# %%
order_payments_df.describe()
# Out:
#        payment_sequential  payment_installments  payment_value
# count       103886.000000         103886.000000  103886.000000
# mean             1.092679              2.853349     154.100380
# std              0.706584              2.687051     217.494064
# min              1.000000              0.000000       0.000000
# 25%              1.000000              1.000000      56.790000
# 50%              1.000000              1.000000     100.000000
# 75%              1.000000              4.000000     171.837500
# max             29.000000             24.000000   13664.080000

# %% [markdown]
# By this far, there is no suspicious data. We will continue to orders_df.

# %%
orders_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99441 entries, 0 to 99440
# Data columns (total 8 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   order_id                       99441 non-null  object
#  1   customer_id                    99441 non-null  object
#  2   order_status                   99441 non-null  object
#  3   order_purchase_timestamp       99441 non-null  object
#  4   order_approved_at              99281 non-null  object
#  5   order_delivered_carrier_date   97658 non-null  object
#  6   order_delivered_customer_date  96476 non-null  object
#  7   order_estimated_delivery_date  99441 non-null  object
# dtypes: object(8)
# memory usage: 6.1+ MB

# %% [markdown]
# Data data type of order_delivered_customer_date should be datetime. We will change it later it data cleaning. Meanwhile order_purchase_timestamp, order_approved_at, order_delivered_carrier_date, and order_estimated_delivery_date are not needed to us, so we will drop them all later.

# %%
orders_df.isna().sum()
# Out:
# order_id                            0
# customer_id                         0
# order_status                        0
# order_purchase_timestamp            0
# order_approved_at                 160
# order_delivered_carrier_date     1783
# order_delivered_customer_date    2965
# order_estimated_delivery_date       0
# dtype: int64

# %% [markdown]
# There are missing values at order_approved_at, order_delivered_carrier_date, and order_delivered_customer_date, but we **do not need** those columns of data to **answer our questions**. We just have to drop all those three columns later in data cleaning.

# %% [markdown]
# Since all the types are object, so we do not need to make statistics describtion of the table. We have to move to products_df.

# %%
products_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32951 entries, 0 to 32950
# Data columns (total 9 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   product_id                  32951 non-null  object
#  1   product_category_name       32341 non-null  object
#  2   product_name_lenght         32341 non-null  float64
#  3   product_description_lenght  32341 non-null  float64
#  4   product_photos_qty          32341 non-null  float64
#  5   product_weight_g            32949 non-null  float64
#  6   product_length_cm           32949 non-null  float64
#  7   product_height_cm           32949 non-null  float64
#  8   product_width_cm            32949 non-null  float64
# dtypes: float64(7), object(2)
# memory usage: 2.3+ MB

# %%
print("Duplications: ", products_df.duplicated().sum())
# Out:
# Duplications:  0

# %% [markdown]
# There is no duplication.

# %%
products_df.isna().sum()
# Out:
# product_id                      0
# product_category_name         610
# product_name_lenght           610
# product_description_lenght    610
# product_photos_qty            610
# product_weight_g                2
# product_length_cm               2
# product_height_cm               2
# product_width_cm                2
# dtype: int64

# %%
missing_values = products_df[products_df['product_category_name'].isnull()]
missing_values
# Out:
#                              product_id product_category_name  \
# 105    a41e356c76fab66334f36de622ecbd3a                   NaN
# 128    d8dee61c2034d6d075997acef1870e9b                   NaN
# 145    56139431d72cd51f19eb9f7dae4d1617                   NaN
# 154    46b48281eb6d663ced748f324108c733                   NaN
# 197    5fb61f482620cb672f5e586bb132eae9                   NaN
# ...                                 ...                   ...
# 32515  b0a0c5dd78e644373b199380612c350a                   NaN
# 32589  10dbe0fbaa2c505123c17fdc34a63c56                   NaN
# 32616  bd2ada37b58ae94cc838b9c0569fecd8                   NaN
# 32772  fa51e914046aab32764c41356b9d4ea4                   NaN
# 32852  c4ceee876c82b8328e9c293fa0e1989b                   NaN
#
#        product_name_lenght  product_description_lenght  product_photos_qty  \
# 105                    NaN                         NaN                 NaN
# ...

# %% [markdown]
# We can see there are 610 missing values at product_category_name, product_name_lenght, product_description_lenght, and product_photos_qty each. We just need product_category_name to answer our questions, so we will fill those 610 missing values to 'unknown'. Then, we will drop the rest column except product_id which we need it too. Since their data types are object. So, we do not need to describe them statistically.

# %%
product_category_name_translation_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 71 entries, 0 to 70
# Data columns (total 2 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   product_category_name          71 non-null     object
#  1   product_category_name_english  71 non-null     object
# dtypes: object(2)
# memory usage: 1.2+ KB

# %%
print("Duplications: ", product_category_name_translation_df.duplicated().sum())
# Out:
# Duplications:  0

# %%
product_category_name_translation_df.isna().sum()
# Out:
# product_category_name            0
# product_category_name_english    0
# dtype: int64

# %% [markdown]
# There is no problem here.

# %% [markdown]
# This is the end of data assessing. We will continue to clean our data in data cleaning.

# %% [markdown]
# ### Cleaning Data

# %% [markdown]
# We start with customer_df. We need to drop customer_zip_code_prefix since we do not need that column in our project.

# %%
customers_df = customers_df.drop('customer_zip_code_prefix', axis=1)
customers_df
# Out:
#                             customer_id                customer_unique_id  \
# 0      06b8999e2fba1a1fbc88172c00ba8bc7  861eff4711a542e4b93843c6dd7febb0
# 1      18955e83d337fd6b2def6b18a428ac77  290c77bc529b7ac935b93aa66c333dc3
# 2      4e7b3e00288586ebd08712fdd0374a03  060e732b5b29e8181a18229c7b0b2b5e
# 3      b2b6027bc5c5109e529d4dc6358b12c3  259dac757896d24d7702b9acbbff3f3c
# 4      4f2d8ab171c80ec8364f7c12e35b23ad  345ecd01c38d18a9036ed96c73b8d066
# ...                                 ...                               ...
# 99436  17ddf5dd5d51696bb3d7c6291687be6f  1a29b476fee25c95fbafc67c5ac95cf8
# 99437  e7b71a9017aa05c9a7fd292d714858e8  d52a67c98be1cf6a5c84435bd38d095d
# 99438  5e28dfe12db7fb50a4b2f691faecea5e  e9f50caf99f032f0bf3c55141f019d99
# 99439  56b18e2166679b8a959d72dd06da27f9  73c2643a0a458b49f58cea58833b192e
# 99440  274fa6071e5e17fe303b9748641082c8  84732c5050c01db9b23e19ba39899398
#
#                customer_city customer_state
# ...

# %% [markdown]
# Next, we move to order_items_df

# %%
order_items_df['shipping_limit_date'] = pd.to_datetime(order_items_df['shipping_limit_date'])
order_items_df
# Out:
#                                 order_id  order_item_id  \
# 0       00010242fe8c5a6d1ba2dd792cb16214              1
# 1       00018f77f2f0320c557190d7a144bdd3              1
# 2       000229ec398224ef6ca0657da4fc703e              1
# 3       00024acbcdf0a6daa1e931b038114c75              1
# 4       00042b26cf59d7ce69dfabb4e55b4fd9              1
# ...                                  ...            ...
# 112645  fffc94f6ce00a00581880bf54a75a037              1
# 112646  fffcd46ef2263f404302a634eb57f7eb              1
# 112647  fffce4705a9662cd70adb13d4a31832d              1
# 112648  fffe18544ffabc95dfada21779c9644f              1
# 112649  fffe41c64501cc87c801fd61db3f6244              1
#
#                               product_id                         seller_id  \
# 0       4244733e06e7ecb4970a6e2683c13e61  48436dade18ac8b2bce089ec2a041202
# 1       e5f2d52b802189ee658865ca93d83a8f  dd7ddc04e1b6c2c614352b383efe2d36
# ...

# %%
order_items_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 112650 entries, 0 to 112649
# Data columns (total 7 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   order_id             112650 non-null  object
#  1   order_item_id        112650 non-null  int64
#  2   product_id           112650 non-null  object
#  3   seller_id            112650 non-null  object
#  4   shipping_limit_date  112650 non-null  datetime64[ns]
#  5   price                112650 non-null  float64
#  6   freight_value        112650 non-null  float64
# dtypes: datetime64[ns](1), float64(2), int64(1), object(3)
# memory usage: 6.0+ MB

# %% [markdown]
# I forgot something! We do not need seller_id and shipping_limit_date columns to answer our qustions. So we better drop them.

# %%
order_items_df = order_items_df.drop(['seller_id', 'shipping_limit_date'], axis=1)
order_items_df
# Out:
#                                 order_id  order_item_id  \
# 0       00010242fe8c5a6d1ba2dd792cb16214              1
# 1       00018f77f2f0320c557190d7a144bdd3              1
# 2       000229ec398224ef6ca0657da4fc703e              1
# 3       00024acbcdf0a6daa1e931b038114c75              1
# 4       00042b26cf59d7ce69dfabb4e55b4fd9              1
# ...                                  ...            ...
# 112645  fffc94f6ce00a00581880bf54a75a037              1
# 112646  fffcd46ef2263f404302a634eb57f7eb              1
# 112647  fffce4705a9662cd70adb13d4a31832d              1
# 112648  fffe18544ffabc95dfada21779c9644f              1
# 112649  fffe41c64501cc87c801fd61db3f6244              1
#
#                               product_id   price  freight_value
# 0       4244733e06e7ecb4970a6e2683c13e61   58.90          13.29
# 1       e5f2d52b802189ee658865ca93d83a8f  239.90          19.93
# 2       c777355d18b72b67abbeef9df44fd0fd  199.00          17.87
# ...

# %% [markdown]
# There is no problem in order_payments_df, so we will move directly to orders_df. We have to drop order_purchase_timestamp, order_approved_at, order_delivered_carrier_date, and order_estimated_delivery_date since they are not needed. Then, we have to change data type of order_delivered_customer_date to be datetime.

# %%
orders_df = orders_df.drop(['order_purchase_timestamp', 'order_approved_at', 'order_delivered_carrier_date', 'order_estimated_delivery_date'], axis=1)
orders_df
# Out:
#                                order_id                       customer_id  \
# 0      e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1      53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 2      47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
# 3      949d5b44dbf5de918fe9c16f97b45f8a  f88197465ea7920adcdbec7375364d82
# 4      ad21c59c0840e6cb83a9ceb5573f8159  8ab97904e6daea8866dbdbc4fb7aad2c
# ...                                 ...                               ...
# 99436  9c5dedf39a927c1b2549525ed64a053c  39bd1228ee8140590ac3aca26f2dfe00
# 99437  63943bddc261676b46f01ca7ac2f7bd8  1fca14ff2861355f6e5f14306ff977a7
# 99438  83c1379a015df1e13d02aae0204711ab  1aa71eb042121263aafbe80c1b562c9c
# 99439  11c177c8e97725db2631073c19f07b62  b331b74b18dc79bcdf6532d51e1637c1
# 99440  66dea50a8b16d9b4dee7af250b4be1a5  edb027a75a1449115f6b43211ae02a24
#
#       order_status order_delivered_customer_date
# ...

# %%
orders_df['order_delivered_customer_date'] = pd.to_datetime(orders_df['order_delivered_customer_date'])
orders_df
# Out:
#                                order_id                       customer_id  \
# 0      e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1      53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 2      47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
# 3      949d5b44dbf5de918fe9c16f97b45f8a  f88197465ea7920adcdbec7375364d82
# 4      ad21c59c0840e6cb83a9ceb5573f8159  8ab97904e6daea8866dbdbc4fb7aad2c
# ...                                 ...                               ...
# 99436  9c5dedf39a927c1b2549525ed64a053c  39bd1228ee8140590ac3aca26f2dfe00
# 99437  63943bddc261676b46f01ca7ac2f7bd8  1fca14ff2861355f6e5f14306ff977a7
# 99438  83c1379a015df1e13d02aae0204711ab  1aa71eb042121263aafbe80c1b562c9c
# 99439  11c177c8e97725db2631073c19f07b62  b331b74b18dc79bcdf6532d51e1637c1
# 99440  66dea50a8b16d9b4dee7af250b4be1a5  edb027a75a1449115f6b43211ae02a24
#
#       order_status order_delivered_customer_date
# ...

# %%
orders_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99441 entries, 0 to 99440
# Data columns (total 4 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   order_id                       99441 non-null  object
#  1   customer_id                    99441 non-null  object
#  2   order_status                   99441 non-null  object
#  3   order_delivered_customer_date  96476 non-null  datetime64[ns]
# dtypes: datetime64[ns](1), object(3)
# memory usage: 3.0+ MB

# %%
orders_df['order_delivered_customer_date'] = pd.to_datetime(orders_df['order_delivered_customer_date'])
orders_df
# Out:
#                                order_id                       customer_id  \
# 0      e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1      53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 2      47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
# 3      949d5b44dbf5de918fe9c16f97b45f8a  f88197465ea7920adcdbec7375364d82
# 4      ad21c59c0840e6cb83a9ceb5573f8159  8ab97904e6daea8866dbdbc4fb7aad2c
# ...                                 ...                               ...
# 99436  9c5dedf39a927c1b2549525ed64a053c  39bd1228ee8140590ac3aca26f2dfe00
# 99437  63943bddc261676b46f01ca7ac2f7bd8  1fca14ff2861355f6e5f14306ff977a7
# 99438  83c1379a015df1e13d02aae0204711ab  1aa71eb042121263aafbe80c1b562c9c
# 99439  11c177c8e97725db2631073c19f07b62  b331b74b18dc79bcdf6532d51e1637c1
# 99440  66dea50a8b16d9b4dee7af250b4be1a5  edb027a75a1449115f6b43211ae02a24
#
#       order_status order_delivered_customer_date
# ...

# %%
orders_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99441 entries, 0 to 99440
# Data columns (total 4 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   order_id                       99441 non-null  object
#  1   customer_id                    99441 non-null  object
#  2   order_status                   99441 non-null  object
#  3   order_delivered_customer_date  96476 non-null  datetime64[ns]
# dtypes: datetime64[ns](1), object(3)
# memory usage: 3.0+ MB

# %%
orders_df['order_delivered_customer_date'] = pd.to_datetime(orders_df['order_delivered_customer_date'])
orders_df
# Out:
#                                order_id                       customer_id  \
# 0      e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1      53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 2      47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
# 3      949d5b44dbf5de918fe9c16f97b45f8a  f88197465ea7920adcdbec7375364d82
# 4      ad21c59c0840e6cb83a9ceb5573f8159  8ab97904e6daea8866dbdbc4fb7aad2c
# ...                                 ...                               ...
# 99436  9c5dedf39a927c1b2549525ed64a053c  39bd1228ee8140590ac3aca26f2dfe00
# 99437  63943bddc261676b46f01ca7ac2f7bd8  1fca14ff2861355f6e5f14306ff977a7
# 99438  83c1379a015df1e13d02aae0204711ab  1aa71eb042121263aafbe80c1b562c9c
# 99439  11c177c8e97725db2631073c19f07b62  b331b74b18dc79bcdf6532d51e1637c1
# 99440  66dea50a8b16d9b4dee7af250b4be1a5  edb027a75a1449115f6b43211ae02a24
#
#       order_status order_delivered_customer_date
# ...

# %%
delivered_orders_df = orders_df.query("order_status == 'delivered'")
delivered_orders_df
# Out:
#                                order_id                       customer_id  \
# 0      e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1      53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 2      47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
# 3      949d5b44dbf5de918fe9c16f97b45f8a  f88197465ea7920adcdbec7375364d82
# 4      ad21c59c0840e6cb83a9ceb5573f8159  8ab97904e6daea8866dbdbc4fb7aad2c
# ...                                 ...                               ...
# 99436  9c5dedf39a927c1b2549525ed64a053c  39bd1228ee8140590ac3aca26f2dfe00
# 99437  63943bddc261676b46f01ca7ac2f7bd8  1fca14ff2861355f6e5f14306ff977a7
# 99438  83c1379a015df1e13d02aae0204711ab  1aa71eb042121263aafbe80c1b562c9c
# 99439  11c177c8e97725db2631073c19f07b62  b331b74b18dc79bcdf6532d51e1637c1
# 99440  66dea50a8b16d9b4dee7af250b4be1a5  edb027a75a1449115f6b43211ae02a24
#
#       order_status order_delivered_customer_date
# ...

# %%
delivered_orders_df.isna().sum()
# Out:
# order_id                         0
# customer_id                      0
# order_status                     0
# order_delivered_customer_date    8
# dtype: int64

# %% [markdown]
# orders_df is done. Now, we move to products_df. We just need product_id and product_category_name. We have to drop the rest. The missing values in product_category name will be filled with 'unknown'.

# %%
products_df = products_df.drop(['product_name_lenght', 'product_description_lenght', 'product_photos_qty', 'product_weight_g', 'product_length_cm', 'product_height_cm', 'product_width_cm'], axis=1)
products_df['product_category_name'] = products_df['product_category_name'].fillna('unknown')
products_df
# Out:
#                              product_id              product_category_name
# 0      1e9e8ef04dbcff4541ed26657ea517e5                         perfumaria
# 1      3aa071139cb16b67ca9e5dea641aaa2f                              artes
# 2      96bd76ec8810374ed1b65e291975717f                      esporte_lazer
# 3      cef67bcfe19066a932b7673e239eb23d                              bebes
# 4      9dc1a7de274444849c219cff195d0b71              utilidades_domesticas
# ...                                 ...                                ...
# 32946  a0b7d5a992ccda646f2d34e418fff5a0                   moveis_decoracao
# 32947  bf4538d88321d0fd4412a93c974510e6  construcao_ferramentas_iluminacao
# 32948  9a7c6041fa9592d9d9ef6cfe62a71f8c                    cama_mesa_banho
# 32949  83808703fc0706a22e264b9d75f04a2e             informatica_acessorios
# 32950  106392145fca363410d287a815be6de4                    cama_mesa_banho
#
# [32951 rows x 2 columns]

# %%
products_df.isna().sum()
# Out:
# product_id               0
# product_category_name    0
# dtype: int64

# %% [markdown]
# That is the end of data cleaning. product_category_name_translation_df does not have problem.

# %% [markdown]
# ## Exploratory Data Analysis (EDA)

# %% [markdown]
# ### Explore Context Number 1

# %%
orders_final_df = pd.merge(order_items_df, delivered_orders_df, on='order_id', how='inner')
orders_final_df
# Out:
#                                 order_id  order_item_id  \
# 0       00010242fe8c5a6d1ba2dd792cb16214              1
# 1       00018f77f2f0320c557190d7a144bdd3              1
# 2       000229ec398224ef6ca0657da4fc703e              1
# 3       00024acbcdf0a6daa1e931b038114c75              1
# 4       00042b26cf59d7ce69dfabb4e55b4fd9              1
# ...                                  ...            ...
# 110192  fffc94f6ce00a00581880bf54a75a037              1
# 110193  fffcd46ef2263f404302a634eb57f7eb              1
# 110194  fffce4705a9662cd70adb13d4a31832d              1
# 110195  fffe18544ffabc95dfada21779c9644f              1
# 110196  fffe41c64501cc87c801fd61db3f6244              1
#
#                               product_id   price  freight_value  \
# 0       4244733e06e7ecb4970a6e2683c13e61   58.90          13.29
# 1       e5f2d52b802189ee658865ca93d83a8f  239.90          19.93
# 2       c777355d18b72b67abbeef9df44fd0fd  199.00          17.87
# ...

# %% [markdown]
# Here, we combine order_items_df and delivered_orders_df to orders_final_df to help us doing EDA.

# %%
merged_df = pd.merge(products_df, product_category_name_translation_df, on='product_category_name', how='inner')
products_final_df = merged_df[['product_id', 'product_category_name_english']]
products_final_df
# Out:
#                              product_id      product_category_name_english
# 0      1e9e8ef04dbcff4541ed26657ea517e5                          perfumery
# 1      6a2fb4dd53d2cdb88e0432f1284a004c                          perfumery
# 2      0d009643171aee696f4733340bc2fdd0                          perfumery
# 3      b1eae565a61935e0011ee7682fef9dc9                          perfumery
# 4      8da90b37f0fb171b4877c124f965b1f6                          perfumery
# ...                                 ...                                ...
# 32323  13b25797ad1e6d6c7cd3cbeb35f8ee7a  furniture_mattress_and_upholstery
# 32324  dc36a7859b743d8610a2bbbaea26ece9  furniture_mattress_and_upholstery
# 32325  107fde0930956120d1e13dd1062fbb46  furniture_mattress_and_upholstery
# 32326  726b4e18f00255e2e63491bcba3f60b8  furniture_mattress_and_upholstery
# 32327  1dceebcc5f23c02ea23e16d5bedca000                  cds_dvds_musicals
#
# [32328 rows x 2 columns]

# %% [markdown]
# Here, we combine products_df and product_category_name_translation_df to products_final_df to help us doing EDA.

# %%
orders_products_df = pd.merge(orders_final_df, products_final_df, on='product_id', how='inner')
orders_products_df
# Out:
#                                 order_id  order_item_id  \
# 0       00010242fe8c5a6d1ba2dd792cb16214              1
# 1       130898c0987d1801452a8ed92a670612              1
# 2       532ed5e14e24ae1f0d735b91524b98b9              1
# 3       6f8c31653edb8c83e1a739408b5ff750              1
# 4       7d19f4ef4d04461989632411b7e588b9              1
# ...                                  ...            ...
# 108633  ffebd80e3291e811c308365936897efd              1
# 108634  ffee31fb4b5e35c9123608015637c495              1
# 108635  fff7c4452f050315db1b3f24d9df5fcd              1
# 108636  fffa82886406ccf10c7b4e35c4ff2788              1
# 108637  fffe41c64501cc87c801fd61db3f6244              1
#
#                               product_id  price  freight_value  \
# 0       4244733e06e7ecb4970a6e2683c13e61   58.9          13.29
# 1       4244733e06e7ecb4970a6e2683c13e61   55.9          17.96
# 2       4244733e06e7ecb4970a6e2683c13e61   64.9          18.33
# ...

# %% [markdown]
# Here, we combine orders_final_df and products_final_df to orders_products_df to help us doing EDA.

# %%
order_count_per_year = orders_products_df['order_delivered_customer_date'].dt.year.value_counts().sort_index()
order_count_per_year
# Out:
# 2016.0      315
# 2017.0    45991
# 2018.0    62324
# Name: order_delivered_customer_date, dtype: int64

# %% [markdown]
# We can see that there are 2017 and 2018 for past 2 years data. Now we will drop the 2016 data.

# %%
rows_to_drop = orders_products_df[orders_products_df['order_delivered_customer_date'].dt.year == 2016].index
orders_products_df = orders_products_df.drop(rows_to_drop)
orders_products_df
# Out:
#                                 order_id  order_item_id  \
# 0       00010242fe8c5a6d1ba2dd792cb16214              1
# 1       130898c0987d1801452a8ed92a670612              1
# 2       532ed5e14e24ae1f0d735b91524b98b9              1
# 3       6f8c31653edb8c83e1a739408b5ff750              1
# 4       7d19f4ef4d04461989632411b7e588b9              1
# ...                                  ...            ...
# 108633  ffebd80e3291e811c308365936897efd              1
# 108634  ffee31fb4b5e35c9123608015637c495              1
# 108635  fff7c4452f050315db1b3f24d9df5fcd              1
# 108636  fffa82886406ccf10c7b4e35c4ff2788              1
# 108637  fffe41c64501cc87c801fd61db3f6244              1
#
#                               product_id  price  freight_value  \
# 0       4244733e06e7ecb4970a6e2683c13e61   58.9          13.29
# 1       4244733e06e7ecb4970a6e2683c13e61   55.9          17.96
# 2       4244733e06e7ecb4970a6e2683c13e61   64.9          18.33
# ...

# %%
order_count_per_year = orders_products_df['order_delivered_customer_date'].dt.year.value_counts().sort_index()
order_count_per_year
# Out:
# 2017.0    45991
# 2018.0    62324
# Name: order_delivered_customer_date, dtype: int64

# %%
orders_products_df.isna().sum()
# Out:
# order_id                         0
# order_item_id                    0
# product_id                       0
# price                            0
# freight_value                    0
# customer_id                      0
# order_status                     0
# order_delivered_customer_date    8
# product_category_name_english    0
# dtype: int64

# %% [markdown]
# We can see there are 8 NaN data in order_delivered_customer_date. We will ignore them all beacuse there is no significat impact if we ignore 8 out of 108323 rows.

# %%
orders_products_2017 = orders_products_df[orders_products_df['order_delivered_customer_date'].dt.year == 2017]
product_counts_2017 = orders_products_2017.groupby(by="product_category_name_english").product_id.nunique().sort_values(ascending=False)
product_counts_2017
# Out:
# product_category_name_english
# bed_bath_table           1554
# sports_leisure           1515
# furniture_decor          1502
# health_beauty            1001
# housewares                990
#                          ...
# security_and_services       2
# cine_photo                  2
# arts_and_craftmanship       2
# cds_dvds_musicals           1
# diapers_and_hygiene         1
# Name: product_id, Length: 71, dtype: int64

# %%
total_items_sold_2017 = orders_products_2017['product_id'].size
total_items_sold_2017
# Out:
# 45991

# %% [markdown]
# We can see the best seller item in 2017 is bed_bath_table with 1554 sold items or 3.38% from all items sold in 2017.

# %%
orders_products_df = pd.merge(orders_products_df, order_payments_df, on='order_id', how='inner')
orders_products_df
# Out:
#                                 order_id  order_item_id  \
# 0       00010242fe8c5a6d1ba2dd792cb16214              1
# 1       130898c0987d1801452a8ed92a670612              1
# 2       532ed5e14e24ae1f0d735b91524b98b9              1
# 3       6f8c31653edb8c83e1a739408b5ff750              1
# 4       7d19f4ef4d04461989632411b7e588b9              1
# ...                                  ...            ...
# 113050  ffebd80e3291e811c308365936897efd              1
# 113051  ffee31fb4b5e35c9123608015637c495              1
# 113052  fff7c4452f050315db1b3f24d9df5fcd              1
# 113053  fffa82886406ccf10c7b4e35c4ff2788              1
# 113054  fffe41c64501cc87c801fd61db3f6244              1
#
#                               product_id  price  freight_value  \
# 0       4244733e06e7ecb4970a6e2683c13e61   58.9          13.29
# 1       4244733e06e7ecb4970a6e2683c13e61   55.9          17.96
# 2       4244733e06e7ecb4970a6e2683c13e61   64.9          18.33
# ...

# %% [markdown]
# We merge orders_products_df with order_payments_df because we want to know what kind of payments the buyers use to buy bed_bath_table.

# %%
filtered_data = orders_products_df[
    (orders_products_df['order_delivered_customer_date'].dt.year == 2017) &
    (orders_products_df['product_category_name_english'] == 'bed_bath_table')
]

payment_type_counts_2017 = filtered_data['payment_type'].value_counts()
payment_type_counts_2017
# Out:
# credit_card    3906
# boleto          817
# voucher         466
# debit_card       26
# Name: payment_type, dtype: int64

# %% [markdown]
# Ok, credit card is the most used. We will see in 2018.

# %%
orders_products_2018 = orders_products_df[orders_products_df['order_delivered_customer_date'].dt.year == 2018]
product_counts_2018 = orders_products_2018.groupby(by="product_category_name_english").product_id.nunique().sort_values(ascending=False)
product_counts_2018
# Out:
# product_category_name_english
# bed_bath_table               1993
# sports_leisure               1783
# health_beauty                1689
# housewares                   1587
# furniture_decor              1430
#                              ...
# la_cuisine                      3
# tablets_printing_image          3
# fashion_childrens_clothes       2
# home_comfort_2                  2
# cds_dvds_musicals               1
# Name: product_id, Length: 70, dtype: int64

# %%
total_items_sold_2018 = orders_products_2018['product_id'].size
total_items_sold_2018
# Out:
# 64641

# %% [markdown]
# We can see the best seller item in 2018 is bed_bath_table with 1993 sold items or 3.2% from all items sold in 2018.

# %%
filtered_data = orders_products_df[
    (orders_products_df['order_delivered_customer_date'].dt.year == 2018) &
    (orders_products_df['product_category_name_english'] == 'bed_bath_table')
]

payment_type_counts_2018 = filtered_data['payment_type'].value_counts()
payment_type_counts_2018
# Out:
# credit_card    4906
# boleto         1041
# voucher         368
# debit_card      112
# Name: payment_type, dtype: int64

# %% [markdown]
# Ok, credit card is the most used. The same in 2017. So, if we want to incrase the sales of bed_bath_table by 30% in the next 1 year we have to add the promotion like cashback to everyone who use credit card as their payment type.

# %% [markdown]
# ### Explore Context Number 2

# %%
orders_products_customers_df = pd.merge(orders_products_df, customers_df, on='customer_id', how='inner')
orders_products_customers_df
# Out:
#                                 order_id  order_item_id  \
# 0       00010242fe8c5a6d1ba2dd792cb16214              1
# 1       130898c0987d1801452a8ed92a670612              1
# 2       532ed5e14e24ae1f0d735b91524b98b9              1
# 3       6f8c31653edb8c83e1a739408b5ff750              1
# 4       7d19f4ef4d04461989632411b7e588b9              1
# ...                                  ...            ...
# 113050  ffebd80e3291e811c308365936897efd              1
# 113051  ffee31fb4b5e35c9123608015637c495              1
# 113052  fff7c4452f050315db1b3f24d9df5fcd              1
# 113053  fffa82886406ccf10c7b4e35c4ff2788              1
# 113054  fffe41c64501cc87c801fd61db3f6244              1
#
#                               product_id  price  freight_value  \
# 0       4244733e06e7ecb4970a6e2683c13e61   58.9          13.29
# 1       4244733e06e7ecb4970a6e2683c13e61   55.9          17.96
# 2       4244733e06e7ecb4970a6e2683c13e61   64.9          18.33
# ...

# %% [markdown]
# We combine orders_products_df and customers_df to help us to dig more in our context.

# %%
cities_2017 = orders_products_customers_df[orders_products_customers_df['order_delivered_customer_date'].dt.year == 2017]
cities_2017 = cities_2017.groupby(by="customer_city").product_id.nunique().sort_values(ascending=False)
cities_2017
# Out:
# customer_city
# sao paulo         4174
# rio de janeiro    2265
# belo horizonte     962
# brasilia           732
# porto alegre       578
#                   ...
# lago verde           1
# ladainha             1
# jussiape             1
# juscimeira           1
# ze doca              1
# Name: product_id, Length: 3136, dtype: int64

# %%
cities_2018 = orders_products_customers_df[orders_products_customers_df['order_delivered_customer_date'].dt.year == 2018]
cities_2018 = cities_2018.groupby(by="customer_city").product_id.nunique().sort_values(ascending=False)
cities_2018
# Out:
# customer_city
# sao paulo                 5798
# rio de janeiro            2633
# belo horizonte            1319
# brasilia                  1069
# curitiba                   794
#                           ...
# pugmil                       1
# governador celso ramos       1
# protasio alves               1
# governador mangabeira        1
# zortea                       1
# Name: product_id, Length: 3328, dtype: int64

# %% [markdown]
# We can see that Sao Paulo, Rio de Janeiro, Belo Horizonter, and Brasilia are being consistently the top 4 to buy products.

# %%
sales_per_city = orders_products_customers_df.groupby('customer_city')['price'].sum().sort_values(ascending=False)
sales_per_city
# Out:
# customer_city
# sao paulo                       1917799.50
# rio de janeiro                   974820.06
# belo horizonte                   350787.11
# brasilia                         302550.45
# curitiba                         210539.64
#                                    ...
# jenipapo de minas                     7.48
# senador jose porfirio                 6.00
# santo antonio do rio abaixo           6.00
# sabaudia                              5.90
# polo petroquimico de triunfo          5.60
# Name: price, Length: 4071, dtype: float64

# %% [markdown]
# We can see in the past 2 years, in the term of sales (price), Sao Paulo, Rio de Janeiro, Belo Horizonter, and Brasilia are being consistently the top 4.

# %% [markdown]
# Giving promotions and more vouchers to other cities might be increasing their sales.

# %% [markdown]
# ### Explore Context Number 3

# %%
customers_2017 = orders_products_customers_df[orders_products_customers_df['order_delivered_customer_date'].dt.year == 2017]
customers_2017 = customers_2017.groupby(by="customer_id").product_id.nunique().sort_values(ascending=False)
customers_2017
# Out:
# customer_id
# 30bb84b541c96af98ba7d90b9ebf35d0    7
# 8c4bcd3c3737198f62421c18e0348554    6
# 223f5e3208f2fa202a8ff706a4d9b206    6
# be1c4e52bb71e0c54b11a26b8e8d59f2    6
# 7171389ea6661b64e8c33ee5ad962922    6
#                                    ..
# 5715e4dd9b8bfeddafcee809661affb6    1
# 57189c2571937e9f5bc62d0d7045fca6    1
# 5718bacbca3da95ebc6d6a33e4a06ca7    1
# 571adf7ec010018c07153bc155499a7b    1
# ffffa3172527f765de70084a7e53aae8    1
# Name: product_id, Length: 40239, dtype: int64

# %% [markdown]
# Customer 30bb84b541c96af98ba7d90b9ebf35d0 is the most loyal customer in 2017 (in terms of items bought).

# %%
customers_2017.describe()
# Out:
# count    40239.000000
# mean         1.039961
# std          0.233280
# min          1.000000
# 25%          1.000000
# 50%          1.000000
# 75%          1.000000
# max          7.000000
# Name: product_id, dtype: float64

# %%
customers_2018 = orders_products_customers_df[orders_products_customers_df['order_delivered_customer_date'].dt.year == 2018]
customers_2018 = customers_2018.groupby(by="customer_id").product_id.nunique().sort_values(ascending=False)
customers_2018
# Out:
# customer_id
# 0d861a5e4dd6a9079d89e1330848f0ab    8
# a67a246af6ba598a14cc86df3c0354ee    7
# 1205480caca6c37f55954da838933b8a    7
# 50920f8cd0681fd86ebe93670c8fe52e    6
# e898b5ef24833b9cb9e2d4f00b937595    6
#                                    ..
# 56c808c1dd74f671f4170b03666749bb    1
# 56c92a5f90b752d7a863d762a08bb3a3    1
# 56c930e539e342f070d8a041f9412e5b    1
# 56ca9dd30b41a32667730b7b3c9b7ad8    1
# ffff42319e9b2d713724ae527742af25    1
# Name: product_id, Length: 54615, dtype: int64

# %% [markdown]
# Customer 0d861a5e4dd6a9079d89e1330848f0ab is the most loyal customer in 2017 (in terms of items bought).

# %%
customers_2018.describe()
# Out:
# count    54615.000000
# mean         1.037096
# std          0.222134
# min          1.000000
# 25%          1.000000
# 50%          1.000000
# 75%          1.000000
# max          8.000000
# Name: product_id, dtype: float64

# %%
customers_buy = orders_products_customers_df.groupby(by="customer_id").product_id.nunique().sort_values(ascending=False)
customers_buy
# Out:
# customer_id
# 0d861a5e4dd6a9079d89e1330848f0ab    8
# a67a246af6ba598a14cc86df3c0354ee    7
# 1205480caca6c37f55954da838933b8a    7
# 30bb84b541c96af98ba7d90b9ebf35d0    7
# 50920f8cd0681fd86ebe93670c8fe52e    6
#                                    ..
# 56df3acf6826046c875a51d0db805524    1
# 56df34401bf8ec42c9d8eeb28e4af0e0    1
# 56df243d9620485f06c20ca3325ca706    1
# 56de1e86668961e5442c922e3762b620    1
# ffffa3172527f765de70084a7e53aae8    1
# Name: product_id, Length: 94862, dtype: int64

# %%
customers_pay = orders_products_customers_df.groupby('customer_id')['price'].sum().sort_values(ascending=False)
customers_pay
# Out:
# customer_id
# 1617b1357756262bfa56ab541c47bc16    13440.00
# de832e8dbb1f588a47013e53feaa67cc    10856.10
# 63b964e79dee32a3587651701a2b8dbf     9888.00
# 6f241d5bbb142b6f764387c8c270645a     9520.14
# 926b6a6fb8b6081e00b335edaf578d35     7998.00
#                                       ...
# 5ac9fcc9259df95cf14d27238b112148        2.99
# d2c63ad286e3ca9dd69218008d61ff81        2.90
# 184e8e8e48937145eb96c721ef1f0747        2.29
# 161b6d415e8b3413c6609c70cf405b5a        0.85
# 9f9d249355f63c5c1216a82b802452c1        0.85
# Name: price, Length: 94862, dtype: float64

# %% [markdown]
# Customer 1617b1357756262bfa56ab541c47bc16 is the most loyal in past 2 years in term of price payed.

# %% [markdown]
# # Visualization

# %% [markdown]
# ### Context 1:

# %%
top_categories = orders_products_customers_df.groupby('product_category_name_english')['product_id'].count().nlargest(20).sort_values()

plt.figure(figsize=(12, 8))
ax = top_categories.plot(kind='barh')
ax.invert_yaxis()
plt.xlabel('Number of Items')
plt.ylabel('Product Category')
plt.title('Top 20 Product Categories by Number of Items Sold')
plt.gca().invert_yaxis()

for i in ax.patches:
    ax.text(i.get_width() + 5, i.get_y() + i.get_height()/2, 
            str(round(i.get_width(), 2)), 
            fontsize=10, color='white', ha='right', va='center', weight='bold')

plt.show()

# %% [markdown]
# We can see top 20 product categoty by items sold in the bar chart above.

# %%
category_counts = orders_products_customers_df['product_category_name_english'].value_counts()
top_categories = category_counts.nlargest(15)
other_categories_count = category_counts[~category_counts.index.isin(top_categories.index)].sum()

plot_data = top_categories.append(pd.Series({'Others': other_categories_count}))

plt.figure(figsize=(12, 8))
plt.pie(plot_data, labels=plot_data.index, autopct='%1.1f%%', startangle=90)
plt.axis('equal') 
plt.title('Distribution of Product Categories by Items Sold')
plt.show()
# Out:
# /var/folders/ct/mtc364rs70d2k9vbv9n041gm0000gn/T/ipykernel_35635/1443352595.py:5: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   plot_data = top_categories.append(pd.Series({'Others': other_categories_count}))

# %% [markdown]
# We can see top 15 product categoty by items sold in percentage above. The other categories who are not included in top 15 can be seen in 'others'.

# %%
category_total_price = orders_products_customers_df.groupby('product_category_name_english')['price'].sum()

top_10_categories = category_total_price.nlargest(20)

plt.figure(figsize=(12, 8))
ax = top_10_categories.plot(kind='barh')
plt.xlabel('Total Price')
plt.ylabel('Product Category')
plt.title('Top 20 Product Categories by Total Price')
plt.gca().invert_yaxis()

for i in ax.patches:
    ax.text(i.get_width() + 100, i.get_y() + i.get_height()/2, 
            '${:,.0f}'.format(i.get_width()), 
            fontsize=10, color='white', ha='right', va='center', weight='bold')

plt.show()

# %% [markdown]
# We can see top 20 product categoty by items sold in the bar chart above.

# %%
top_15_categories = category_total_price.nlargest(15)

other_categories_total_price = category_total_price[~category_total_price.index.isin(top_15_categories.index)]
others_total_price = other_categories_total_price.sum()
top_15_categories['Others'] = others_total_price

plt.figure(figsize=(12, 8))
plt.pie(top_15_categories, labels=top_15_categories.index, autopct='%1.1f%%', startangle=90)
plt.axis('equal') 
plt.title('Total Price Distribution per Product Category')
plt.show()

# %% [markdown]
# We can see top 15 product categoty by items sold in percentage above. The other categories who are not included in top 15 can be seen in 'others'.

# %%
bed_bath_table_df = orders_products_customers_df[orders_products_customers_df['product_category_name_english'] == 'bed_bath_table']

payment_type_counts = bed_bath_table_df['payment_type'].value_counts()

plt.figure(figsize=(12, 8))
plt.pie(payment_type_counts, labels=payment_type_counts.index, autopct='%1.1f%%', startangle=90)
plt.axis('equal')  
plt.title('Payment Type Distribution for Bed Bath Table Products')
plt.show()

# %% [markdown]
# We can see the payment type of the best sellet product categoty by item sold.

# %%
health_beauty_df = orders_products_customers_df[orders_products_customers_df['product_category_name_english'] == 'health_beauty']

payment_type_counts = health_beauty_df['payment_type'].value_counts()

plt.figure(figsize=(12, 8))
plt.pie(payment_type_counts, labels=payment_type_counts.index, autopct='%1.1f%%', startangle=90)
plt.axis('equal')  
plt.title('Payment Type Distribution for Health Beauty Products')
plt.show()

# %% [markdown]
# We can see the payment type of the best sellet product categoty by price payed.

# %% [markdown]
# ### Context 2:

# %%
city_max_items = orders_products_customers_df.groupby('customer_city')['order_item_id'].max()

# Sort the cities by the maximum number of items sold
sorted_cities = city_max_items.sort_values(ascending=False)

# Select the top 10 cities
top_10_cities = sorted_cities.head(20)

# Create a horizontal bar plot
plt.figure(figsize=(12, 8))
ax = top_10_cities.plot(kind='barh')
plt.xlabel('Max Number of Items Sold')
plt.ylabel('City')
plt.title('Top 20 Cities by Max Number of Items Sold')
plt.gca().invert_yaxis()  # Invert the y-axis to display the highest number of items at the top

# Add value annotations to each bar
for i in ax.patches:
    # get_width pulls left or right; get_y pushes up or down
    ax.text(i.get_width() + 0.001, i.get_y() + i.get_height()/2, 
            str(int(i.get_width())), 
            fontsize=10, color='white', ha='right', va='center', weight='bold')

plt.show()

# %% [markdown]
# The most items sold is by customer in Sao Paulo. Following by Goiania and Uniao da Vitoria.

# %%
city_max_price = orders_products_customers_df.groupby('customer_city')['price'].sum()

# Sort the cities by the maximum total price of items sold
sorted_cities = city_max_price.sort_values(ascending=False)

# Select the top 10 cities
top_10_cities = sorted_cities.head(20)

# Create a horizontal bar plot
plt.figure(figsize=(12, 8))
ax = top_10_cities.plot(kind='barh')
plt.xlabel('Max Total Price of Items Sold')
plt.ylabel('City')
plt.title('Top 10 Cities by Max Total Price of Items Sold')
plt.gca().invert_yaxis()  # Invert the y-axis to display the highest total price at the top

# Add value annotations to each bar
for i in ax.patches:
    # get_width pulls left or right; get_y pushes up or down
    ax.text(i.get_width() + 50, i.get_y() + i.get_height()/2, 
            '${:,.0f}'.format(i.get_width()), 
            fontsize=10, color='black', ha='left', va='center')

plt.show()

# %% [markdown]
# If we talk about the amount of money spent by customers, then customers in Sao Paulo are the most spending.

# %%
city_total_price = orders_products_customers_df.groupby('customer_city')['price'].sum()

# Select the top 15 cities
top_15_cities = city_total_price.nlargest(15)

# Combine the rest of the cities into 'Others'
other_cities_total_price = city_total_price[~city_total_price.index.isin(top_15_cities.index)]
others_total_price = other_cities_total_price.sum()
top_15_cities['Others'] = others_total_price

# Create a pie chart
plt.figure(figsize=(12, 8))
plt.pie(top_15_cities, labels=top_15_cities.index, autopct='%1.1f%%', startangle=90)
plt.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle
plt.title('Total Price Distribution per Customer City')
plt.show()

# %% [markdown]
# Here we can see that Sao Paulo customers spend 14.1% of products price that made in 2017 and 2018. We show top 15 citites here, meanwhile the rests are grouped to 'others'.

# %% [markdown]
# ### Context 3:

# %%
customer_buy_pay = pd.merge(customers_buy, customers_pay, on='customer_id', how='inner')
customer_buy_pay
# Out:
#                                   product_id    price
# customer_id
# 0d861a5e4dd6a9079d89e1330848f0ab           8  1138.30
# a67a246af6ba598a14cc86df3c0354ee           7   563.00
# 1205480caca6c37f55954da838933b8a           7   186.59
# 30bb84b541c96af98ba7d90b9ebf35d0           7  1093.00
# 50920f8cd0681fd86ebe93670c8fe52e           6   920.31
# ...                                      ...      ...
# 56df3acf6826046c875a51d0db805524           1    64.90
# 56df34401bf8ec42c9d8eeb28e4af0e0           1    12.50
# 56df243d9620485f06c20ca3325ca706           1   149.99
# 56de1e86668961e5442c922e3762b620           1   117.00
# ffffa3172527f765de70084a7e53aae8           1    21.80
#
# [94862 rows x 2 columns]

# %% [markdown]
# We merge customer_id, product_id (sum), and price to help us in context 3.

# %%
customer_buy_pay.duplicated().sum()
# Out:
# 85863

# %% [markdown]
# Here wwe find duplicates, so we have to drop them.

# %%
customer_buy_pay = customer_buy_pay.drop_duplicates()

# %%
customer_buy_pay = customer_buy_pay.drop_duplicates()
customer_buy_pay
# Out:
#                                   product_id    price
# customer_id
# 0d861a5e4dd6a9079d89e1330848f0ab           8  1138.30
# a67a246af6ba598a14cc86df3c0354ee           7   563.00
# 1205480caca6c37f55954da838933b8a           7   186.59
# 30bb84b541c96af98ba7d90b9ebf35d0           7  1093.00
# 50920f8cd0681fd86ebe93670c8fe52e           6   920.31
# ...                                      ...      ...
# 56a5ff92ab3fa86a9dea8ec5f53292d8           1    30.65
# 5708c0f571740069a74aa7902b11932a           1   176.50
# 5707eae9fa7163a38f01a3147b1b046b           1   138.52
# 56e7899b07b9a515442d8855a6e049b3           1   238.70
# 56d6082f14bf0030bbc257ee81aaed82           1   203.40
#
# [8999 rows x 2 columns]

# %%
customer_buy_pay = customer_buy_pay.rename(columns={'product_id': 'product_bought'})

# %%
data = customer_buy_pay
rfm = data.groupby('customer_id').agg({
    'product_bought': 'sum',
    'price': 'sum'
})

rfm.columns = ['Frequency', 'Monetary']

rfm['Frequency_score'] = pd.qcut(rfm['Frequency'].rank(method='first'), q=3, labels=False)
rfm['Monetary_score'] = pd.qcut(rfm['Monetary'], q=3, labels=False)

rfm['FM_score'] = rfm['Frequency_score'].astype(str) + rfm['Monetary_score'].astype(str)

seg_map = {
    r'[0-1][0-1]': 'Low Value',
    r'[0-1]2': 'Medium Value',
    r'2[0-1]': 'Medium Value',
    r'22': 'High Value'
}

rfm['Segment'] = rfm['Frequency_score'].astype(str) + rfm['Monetary_score'].astype(str)
rfm['Segment'] = rfm['Segment'].replace(seg_map, regex=True)

segment_counts = rfm['Segment'].value_counts()

plt.figure(figsize=(8, 8))
plt.pie(segment_counts, labels=segment_counts.index, autopct='%1.1f%%')
plt.title('Customer Segmentation')
plt.axis('equal')
plt.show()

# %% [markdown]
# Here we can see the result of RFM analysis in a pie chart. We devide the customers by 3 types:
# 1. high value
# 2. medium value
# 3. low value
#
# Wee devide them based on how many products they bought and how much money they spent.

# %% [markdown]
# ## Conclusion

# %% [markdown]
# ### Context 1
# - which product category has the highest number of sales in the past 2 years?
# in term of items sold is bed_bath_table and in term of price is health_beauty.
# - what percentage did the best-selling product contribute to total sales in the same period?
# bed_bath_table contribute 10.3% and health_beauty contribute 9.3%.
# - what promotional strategies can be implemented to increase sales of this best-selling product by 20% in the next 1 year?
# we increase promotion for bed_bath_table and health_beauty or make voucher for them. Especially for credit card users.
#
# ### Context 2
# - which city has the highest number of products bought over the past 2 years?
# In term of price and items sold are both Sao Paulo.
# - what percentage did the city contribute to the company's total revenue over the same period?
# Sao Paulo contribute 14.1%.
# - how to increase the number of orders from other cities by 20% in the next 1 year?
# We have to make promotions and vouchers for those cities. Also, we can cut the price of delivery fee.
#
# ### Context 3
# - what percentage of loyal customers and order a lot?
# 10.8%
# - what percentage of loyal customers but order a little at a time and rarely-buy customers but immediately a lot?
# 45.1%
# - what percentage of rarely-buy customers and only a little?
# 44.1%
